# %%
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_csv('../data/dnaq_history_data_2022_ext.csv')

# %%
df.head()
# Out:
#         fault_type          P   COS  Ia    Ib    Ic   Ua   Ub   Uc  \
# 0               分闸   0.000000  0.00   0   0.0   0.0  381  380  380
# 1               合闸  32.599998  0.91  58  61.0  59.0  375  373  377
# 2               分闸   0.000000  0.00   0   0.0   0.0  372  371  373
# 3               分闸   0.000000  0.00   0   0.0   0.0  372  373  372
# 4               合闸  33.299999  0.90  59  61.0  60.0  378  375  376
# ...            ...        ...   ...  ..   ...   ...  ...  ...  ...
# 2123548         合闸  35.500000  0.90  63  65.0  62.0  376  372  377
# 2123549         分闸   0.000000  0.00   0   0.0   0.0  382  381  382
# 2123550         合闸  12.800000  0.89  23  23.0  23.0  371  370  370
# 2123551         分闸   0.000000  0.00   0   0.0   0.0  383  377  376
# 2123552         分闸   0.000000  0.00   0   0.0   0.0  379  377  381
#
#          elec_degree      collection_time
# 0              78405  2022-01-01 00:00:04
# 1             490384  2022-01-01 00:00:07
# ...

# %%
# 提取有用字段
df = df[["fault_type", "P", "COS", "Ia", "Ib", "Ic", "Ua", "Ub", "Uc", "elec_degree", "collection_time"]]
df.head()
# Out:
#   fault_type          P   COS  Ia    Ib    Ic   Ua   Ub   Uc  elec_degree  \
# 0         分闸   0.000000  0.00   0   0.0   0.0  381  380  380        78405
# 1         合闸  32.599998  0.91  58  61.0  59.0  375  373  377       490384
# 2         分闸   0.000000  0.00   0   0.0   0.0  372  371  373       276878
# 3         分闸   0.000000  0.00   0   0.0   0.0  372  373  372       198436
# 4         合闸  33.299999  0.90  59  61.0  60.0  378  375  376        33039
#
#        collection_time
# 0  2022-01-01 00:00:04
# 1  2022-01-01 00:00:07
# 2  2022-01-01 00:00:10
# 3  2022-01-01 00:00:14
# 4  2022-01-01 00:00:17

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2123553 entries, 0 to 2123552
# Data columns (total 11 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   fault_type       object
#  1   P                float64
#  2   COS              float64
#  3   Ia               int64
#  4   Ib               float64
#  5   Ic               float64
#  6   Ua               int64
#  7   Ub               int64
#  8   Uc               int64
#  9   elec_degree      int64
#  10  collection_time  object
# dtypes: float64(4), int64(5), object(2)
# memory usage: 178.2+ MB

# %%
# 查看缺失值情况
import missingno as msno
msno.matrix(df)
# Out:
# <Axes: >
